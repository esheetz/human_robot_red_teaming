# %% [markdown]
# # Colab/Drive Setup

# %%
from google.colab import drive
from google.colab import runtime
drive.mount('/content/gdrive')
# %cd gdrive/MyDrive/Object\ Affordances/HRRT/human_robot_red_teaming
# %ls
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Object Affordances/HRRT/human_robot_red_teaming
# chatbot_hrrting.ipynb  config/  docs/  hrrt_testing.ipynb  README.md  scripts/

# %%
# %cd ../
# %ls
# %cd human_robot_red_teaming
# %cd scripts/
# %ls
# Out:
# /content/gdrive/MyDrive/Object Affordances/HRRT/human_robot_red_teaming/scripts
# hrrt2.py  hrrt3.py  hrrt4.py  __pycache__/  yaml_formatting_checks.py

# %% [markdown]
# # HRRT Imports

# %%
from yaml_formatting_checks import KBFormatting, ModelFormatting
from hrrt2 import hrrt2, hrrt2_abridged_transcript, process_chatbot_hrrt2_text, write_hrrt2_yaml
from hrrt3 import hrrt3, process_chatbot_hrrt3_text, write_hrrt3_yaml
from hrrt4 import hrrt4, hrrt4_abridged_transcript, process_chatbot_hrrt4_reflection_text, process_chatbot_hrrt4_updated_yaml, write_hrrt4_yaml

# %% [markdown]
# # Domain Prompts

# %% [markdown]
# ## Lunar Habitat Airlock
#
# Scenario: A robot is on the lunar surface, assisting astronauts living in a habitat with science experiments and space exploration tasks. The pressurized lunar habitat has an airlock, with two doors on either side. One door from the pressurized habitat to the airlock chamber, one door from the airlock chamber to the lunar surface.

# %% [markdown]
# # General Instructions
#
# Goal: We need to make sure the robot has a sufficiently complex model of the scenario to perform tasks safely.
#
# The robot's model consists of states (symbolic literals or lists of mutually exclusive (mutex) states) and actions (name, pre-condition states, added post-condition states, and removed post-condition states). You will be prompted with questions to explore the robot's model and provide improvements.
#
# Here's the robot's model (formatted as a YAML file):

# %% [markdown]
# ## [TODO: copy model YAML file into ChatGPT]

# %% [markdown]
# # Simplified Prompts (Used in Favor of More Detailed Prompts Below)

# %% [markdown]
# * Give ChatGPT initial prompt based on Domain Prompt and General Instructions, above.
# * If ChatGPT does not offer initial reflections, prompt: "Please tell me about invalid state combinations, action feasibility, and assumption inconsistencies."
# * After initial suggestions, prompt: "How would you fix the [1-2 suggestions, use words directly from ChatGPT]?"
# * After revisions, share reflection questions: [See prompt below]
# * After these reflections, prompt: "Thank you! Please update your revised model to include [1-3 suggestions, use words directly from ChatGPT]."
#
# ## Reflection Prompt
#
# ```
# Perfect, thank you! Let's use that as our new model. Please consider the following questions:
#
# ==================== HRRT LEVEL 4 REFLECTIONS ====================
#
# Are there additional tasks the robot should be taking on?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# What important information may still be missing from the model?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# What should an agent know when completing tasks in this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# What catastrophic failures could occur in this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# Are there external, independently verified resources for identifying failure cases in this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# What are undesirable outcomes (not necessarily catastrophic failures) for this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# How much can an agent trust other agents in this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# What are unlikely or remote possibilities that may occur in this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# Please respond to the Blue Team reflection questions.
# ```

# %% [markdown]
# # Read in Knowledge Base and Model

# %%
# set domain
domain = "lunar_habitat_airlock"
# set model number
model_num = 1

kb_file = "../config/" + domain + "/knowledge_base.yaml"
model_file = "../config/" + domain + "/model" + str(model_num) + ".yaml"

success, kb = KBFormatting.format_kb(kb_file)
if success:
  print("KNOWLEDGE BASE READING SUCCESSFUL!")
else:
  print("Knowledge base reading failed :(")

succes, model = ModelFormatting.format_model(model_file)
if success:
  print("MODEL READING SUCCESSFUL!")
else:
  print("Model reading failed :(")
# Out:
# KNOWLEDGE BASE READING SUCCESSFUL!
# MODEL READING SUCCESSFUL!

# %% [markdown]
# # Human-Robot Red Teaming Levels

# %% [markdown]
# ## HRRT Level 2

# %% [markdown]
# ### Prompt for ChatGPT

# %% [markdown]
# General prompt:
#
# Great. Now using this model you just created, are all possible states (all combinations of states) always valid (safe, feasible, etc.)?
#
# Yes, please further refine the model to fix these issues.

# %%
# initialize HRRT Level 2
print("Please fill in the blanks with [Y/N] for yes/no to answer the following questions:")
print()
print()
print()
possibilities = hrrt2(model, interactive=False)
# Out:
# Please fill in the blanks with [Y/N] for yes/no to answer the following questions:
#
#
#
# Found possible state: ['door_habitat_airlock_unlocked_opened']
#     within which it is possible to take action lock_close_door_habitat_airlock
#     Is this possibility always valid (safe, feasible, etc.)? (Y/N) __________
#
# Found possible state: ['door_airlock_surface_unlocked_opened']
#     within which it is possible to take action lock_close_door_airlock_surface
#     Is this possibility always valid (safe, feasible, etc.)? (Y/N) __________
#
# Found possible state: ['robot_inside_habitat', 'door_habitat_airlock_unlocked_opened']
#     within which it is possible to take action lock_close_door_habitat_airlock
#     Is this possibility always valid (safe, feasible, etc.)? (Y/N) __________
#
# Found possible state: ['robot_inside_airlock', 'door_habitat_airlock_unlocked_opened']
#     within which it is possible to take action lock_close_door_habitat_airlock
# ...

# %%
print("Found " + str(len(possibilities)) + " possibilities to validate on HRRT Level 2")
# Out:
# Found 104 possibilities to validate on HRRT Level 2

# %%
# initialize HRRT Level 2
print("Please fill in the blanks with [Y/N] for yes/no to answer the following questions:")
print()
print()
print()
hrrt2_abridged_transcript(possibilities)
# Out:
# Please fill in the blanks with [Y/N] for yes/no to answer the following questions:
#
#
#
# Found possible state: ['robot_inside_airlock', 'door_habitat_airlock_unlocked_opened', 'door_airlock_surface_unlocked_closed']
#     Is this possibility always valid (safe, feasible, etc.)? (Y/N) __________
#
# Found possible state: ['door_habitat_airlock_unlocked_opened', 'door_airlock_surface_unlocked_closed']
#     Is this possibility always valid (safe, feasible, etc.)? (Y/N) __________
#
# Found possible state: ['door_airlock_surface_unlocked_opened', 'robot_has_key']
#     Is this possibility always valid (safe, feasible, etc.)? (Y/N) __________
#
# Found possible state: ['robot_inside_airlock', 'door_airlock_surface_unlocked_opened']
#     Is this possibility always valid (safe, feasible, etc.)? (Y/N) __________
#
# Found possible state: ['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'robot_has_key']
# ...

# %% [markdown]
# ### [TODO: copy and paste output into ChatGPT]

# %% [markdown]
# ### ChatGPT's Response

# %%
hrrt2_raw_text = '''
['robot_inside_airlock', 'door_habitat_airlock_unlocked_opened', 'door_airlock_surface_unlocked_closed'] [N]  # Unsafe due to potential pressure loss
['door_habitat_airlock_unlocked_opened', 'door_airlock_surface_unlocked_closed'] [N]  # Unsafe without robot managing airlock
['door_airlock_surface_unlocked_opened', 'robot_has_key'] [N]  # Decompression risk without airlock pressure control
['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'door_habitat_airlock_locked_closed'] [N]  # Risk of decompression
['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'door_habitat_airlock_unlocked_closed'] [N]  # Potential decompression risk
['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'door_habitat_airlock_unlocked_opened'] [N]  # Major decompression risk
['robot_inside_airlock', 'door_airlock_surface_locked_opened', 'door_habitat_airlock_locked_closed'] [N]  # Locked door open is illogical
['robot_inside_airlock', 'door_airlock_surface_locked_opened', 'door_habitat_airlock_unlocked_closed'] [N]  # Inconsistent state
['robot_inside_airlock', 'door_airlock_surface_locked_opened', 'door_habitat_airlock_unlocked_opened'] [N]  # Airlock safety compromised
['robot_inside_airlock', 'door_airlock_surface_locked_closed', 'door_habitat_airlock_unlocked_opened'] [N]  # Airlock pressurization concern
['robot_inside_airlock', 'door_airlock_surface_locked_closed', 'door_habitat_airlock_locked_opened'] [N]  # Locked door open is invalid
['robot_inside_airlock', 'door_airlock_surface_locked_closed', 'door_habitat_airlock_locked_closed'] [Y]  # Safe and sealed state
['robot_inside_airlock', 'door_airlock_surface_locked_closed', 'door_habitat_airlock_unlocked_closed'] [Y]  # Safe with both doors closed
['robot_inside_airlock', 'door_airlock_surface_unlocked_closed', 'door_habitat_airlock_locked_opened'] [N]  # Locked door open is invalid
['robot_inside_airlock', 'door_airlock_surface_unlocked_closed', 'door_habitat_airlock_locked_closed'] [Y]  # Safe with both doors closed
['robot_inside_airlock', 'door_airlock_surface_unlocked_closed', 'door_habitat_airlock_unlocked_opened'] [N]  # Airlock safety compromised
['robot_inside_airlock', 'door_airlock_surface_unlocked_closed', 'door_habitat_airlock_unlocked_closed'] [Y]  # Safe, doors closed
['door_airlock_surface_locked_closed', 'door_habitat_airlock_unlocked_opened'] [N]  # Airlock safety compromised
['door_airlock_surface_locked_closed', 'door_habitat_airlock_locked_opened'] [N]  # Locked door open is invalid
['door_airlock_surface_locked_closed', 'door_habitat_airlock_locked_closed'] [Y]  # Safe, sealed environment
['door_airlock_surface_locked_closed', 'door_habitat_airlock_unlocked_closed'] [Y]  # Safe, both doors closed
['door_airlock_surface_unlocked_closed', 'door_habitat_airlock_locked_opened'] [N]  # Locked door open is invalid
['door_airlock_surface_unlocked_closed', 'door_habitat_airlock_locked_closed'] [Y]  # Safe, sealed
['door_airlock_surface_unlocked_closed', 'door_habitat_airlock_unlocked_opened'] [N]  # Compromised safety
['door_airlock_surface_unlocked_closed', 'door_habitat_airlock_unlocked_closed'] [Y]  # Safe, doors closed
'''

hrrt2_raw_yaml_format = '''
states:

  - name: ['robot_inside_airlock', 'door_habitat_airlock_unlocked_opened', 'door_airlock_surface_unlocked_closed']
    valid: N
    reason: Unsafe due to potential pressure loss

  - name: ['door_habitat_airlock_unlocked_opened', 'door_airlock_surface_unlocked_closed']
    valid: N
    reason: Unsafe without robot managing airlock

  - name: ['door_airlock_surface_unlocked_opened', 'robot_has_key']
    valid: N
    reason: Decompression risk without airlock pressure control

  - name: ['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'door_habitat_airlock_locked_closed']
    valid: N
    reason: Risk of decompression

  - name: ['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'door_habitat_airlock_unlocked_closed']
    valid: N
    reason: Potential decompression risk

  - name: ['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'door_habitat_airlock_unlocked_opened']
    valid: N
    reason: Major decompression risk

  - name: ['robot_inside_airlock', 'door_airlock_surface_locked_opened', 'door_habitat_airlock_locked_closed']
    valid: N
    reason: Locked door open is illogical

  - name: ['robot_inside_airlock', 'door_airlock_surface_locked_opened', 'door_habitat_airlock_unlocked_closed']
    valid: N
    reason: Inconsistent state

  - name: ['robot_inside_airlock', 'door_airlock_surface_locked_opened', 'door_habitat_airlock_unlocked_opened']
    valid: N
    reason: Airlock safety compromised

  - name: ['robot_inside_airlock', 'door_airlock_surface_locked_closed', 'door_habitat_airlock_unlocked_opened']
    valid: N
    reason: Airlock pressurization concern

  - name: ['robot_inside_airlock', 'door_airlock_surface_locked_closed', 'door_habitat_airlock_locked_opened']
    valid: N
    reason: Locked door open is invalid

  - name: ['robot_inside_airlock', 'door_airlock_surface_locked_closed', 'door_habitat_airlock_locked_closed']
    valid: Y
    reason: Safe and sealed state

  - name: ['robot_inside_airlock', 'door_airlock_surface_locked_closed', 'door_habitat_airlock_unlocked_closed']
    valid: Y
    reason: Safe with both doors closed

  - name: ['robot_inside_airlock', 'door_airlock_surface_unlocked_closed', 'door_habitat_airlock_locked_opened']
    valid: N
    reason: Locked door open is invalid

  - name: ['robot_inside_airlock', 'door_airlock_surface_unlocked_closed', 'door_habitat_airlock_locked_closed']
    valid: Y
    reason: Safe with both doors closed

  - name: ['robot_inside_airlock', 'door_airlock_surface_unlocked_closed', 'door_habitat_airlock_unlocked_opened']
    valid: N
    reason: Airlock safety compromised

  - name: ['robot_inside_airlock', 'door_airlock_surface_unlocked_closed', 'door_habitat_airlock_unlocked_closed']
    valid: Y
    reason: Safe, doors closed

  - name: ['door_airlock_surface_locked_closed', 'door_habitat_airlock_unlocked_opened']
    valid: N
    reason: Airlock safety compromised

  - name: ['door_airlock_surface_locked_closed', 'door_habitat_airlock_locked_opened']
    valid: N
    reason: Locked door open is invalid

  - name: ['door_airlock_surface_locked_closed', 'door_habitat_airlock_locked_closed']
    valid: Y
    reason: Safe, sealed environment

  - name: ['door_airlock_surface_locked_closed', 'door_habitat_airlock_unlocked_closed']
    valid: Y
    reason: Safe, both doors closed

  - name: ['door_airlock_surface_unlocked_closed', 'door_habitat_airlock_locked_opened']
    valid: N
    reason: Locked door open is invalid

  - name: ['door_airlock_surface_unlocked_closed', 'door_habitat_airlock_locked_closed']
    valid: Y
    reason: Safe, sealed

  - name: ['door_airlock_surface_unlocked_closed', 'door_habitat_airlock_unlocked_opened']
    valid: N
    reason: Compromised safety

  - name: ['door_airlock_surface_unlocked_closed', 'door_habitat_airlock_unlocked_closed']
    valid: Y
    reason: Safe, doors closed
'''

# %%
import yaml

yaml_dict = yaml.load(hrrt2_raw_yaml_format, Loader=yaml.FullLoader)
print(yaml_dict)
# Out:
# {'states': [{'name': ['robot_inside_airlock', 'door_habitat_airlock_unlocked_opened', 'door_airlock_surface_unlocked_closed'], 'valid': 'N', 'reason': 'Unsafe due to potential pressure loss'}, {'name': ['door_habitat_airlock_unlocked_opened', 'door_airlock_surface_unlocked_closed'], 'valid': 'N', 'reason': 'Unsafe without robot managing airlock'}, {'name': ['door_airlock_surface_unlocked_opened', 'robot_has_key'], 'valid': 'N', 'reason': 'Decompression risk without airlock pressure control'}, {'name': ['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'door_habitat_airlock_locked_closed'], 'valid': 'N', 'reason': 'Risk of decompression'}, {'name': ['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'door_habitat_airlock_unlocked_closed'], 'valid': 'N', 'reason': 'Potential decompression risk'}, {'name': ['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'door_habitat_airlock_unlocked_opened'], 'valid': 'N', 'reason': 'Major decompression risk'
# ...

# %% [markdown]
# ### [TODO: copy and paste output from ChatGPT into file for later reference]

# %% [markdown]
# ### Validate Possibilities and Save to File

# %%
# process text from ChatGPT
validated_possibilities = process_chatbot_hrrt2_text(possibilities, raw_text=hrrt2_raw_text)
# save to file
write_hrrt2_yaml(validated_possibilities, model_file)
# Out:
# WARN: could not find in possibilities list, parsed state ['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'door_habitat_airlock_locked_closed']
# WARN: could not find in possibilities list, parsed state ['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'door_habitat_airlock_unlocked_closed']
# WARN: could not find in possibilities list, parsed state ['robot_inside_airlock', 'door_airlock_surface_unlocked_opened', 'door_habitat_airlock_unlocked_opened']
# WARN: could not find in possibilities list, parsed state ['robot_inside_airlock', 'door_airlock_surface_locked_opened', 'door_habitat_airlock_locked_closed']
# WARN: could not find in possibilities list, parsed state ['robot_inside_airlock', 'door_airlock_surface_locked_opened', 'door_habitat_airlock_unlocked_closed']
# WARN: could not find in possibilities list, parsed state ['robot_inside_airlock', 'door_airlock_surface_locked_opened', 'door_habitat_airlock_unlocked_opened']
# ...

# %%
print(possibilities)
# Out:
# [(['door_habitat_airlock_unlocked_opened'], 'lock_close_door_habitat_airlock', ['door_habitat_airlock_locked_closed'], None), (['door_airlock_surface_unlocked_opened'], 'lock_close_door_airlock_surface', ['door_airlock_surface_locked_closed'], None), (['robot_inside_habitat', 'door_habitat_airlock_unlocked_opened'], 'lock_close_door_habitat_airlock', ['robot_inside_habitat', 'door_habitat_airlock_locked_closed'], None), (['robot_inside_airlock', 'door_habitat_airlock_unlocked_opened'], 'lock_close_door_habitat_airlock', ['robot_inside_airlock', 'door_habitat_airlock_locked_closed'], None), (['robot_outside_habitat', 'door_habitat_airlock_unlocked_opened'], 'lock_close_door_habitat_airlock', ['robot_outside_habitat', 'door_habitat_airlock_locked_closed'], None), (['robot_inside_habitat', 'door_airlock_surface_unlocked_opened'], 'lock_close_door_airlock_surface', ['robot_inside_habitat', 'door_airlock_surface_locked_closed'], None), (['robot_inside_airlock', 'door_airlock_surface_unloc
# ...

# %% [markdown]
# ## HRRT Level 3

# %% [markdown]
# ### Prompt for ChatGPT

# %% [markdown]
# Now please consider the implicit assumptions present in the defined actions. Can all pre-condition states be achieved in order to perform the actions? Will all post-condition states be achieved as a result of performing the actions? Are these assumptions always valid?

# %%
# initialize HRRT Level 3
print("Please fill in the blanks with [Y/N] for yes/no to answer the following questions:")
print()
print()
print()
assumptions = hrrt3(model, interactive=False)
# Out:
# Please fill in the blanks with [Y/N] for yes/no to answer the following questions:
#
#
#
# Implicit assumption that pre-condition state robot_inside_habitat can be achieved to perform action unlock_open_door_habitat_airlock
#     Is this assumption always valid? (Y/N) __________
#
# Implicit assumption that pre-condition state robot_has_key can be achieved to perform action unlock_open_door_habitat_airlock
#     Is this assumption always valid? (Y/N) __________
#
# Implicit assumption that pre-condition state robot_inside_airlock can be achieved to perform action unlock_open_door_airlock_surface
#     Is this assumption always valid? (Y/N) __________
#
# Implicit assumption that pre-condition state robot_has_key can be achieved to perform action unlock_open_door_airlock_surface
#     Is this assumption always valid? (Y/N) __________
#
# Implicit assumption that pre-condition state robot_inside_habitat can be achieved to perform action enter_airlock_from_habitat
# ...

# %% [markdown]
# ### [TODO: copy and paste output into ChatGPT]

# %% [markdown]
# ### ChatGPT's Response

# %%
hrrt3_raw_text = '''
Here are the answers based on the scenario's constraints, potential failure modes, and operational dependencies:

robot_inside_habitat → unlock_open_door_habitat_airlock: (Y) – The robot starts inside the habitat, making this achievable.
robot_has_key → unlock_open_door_habitat_airlock: (N) – The key may not always be available to the robot.
robot_inside_airlock → unlock_open_door_airlock_surface: (Y) – The robot must enter the airlock first, which is generally achievable.
robot_has_key → unlock_open_door_airlock_surface: (N) – Similar to #2, the key’s availability is not guaranteed.
robot_inside_habitat → enter_airlock_from_habitat: (Y) – This is the robot’s initial state, generally valid.
door_habitat_airlock_unlocked_opened → enter_airlock_from_habitat: (N) – Mechanical failure or lock issues may prevent this.
door_airlock_surface_locked_closed → enter_airlock_from_habitat: (Y) – This state is typically maintained before airlock entry for safety.
robot_inside_airlock → enter_surface_from_airlock: (Y) – The robot can achieve this if prior steps succeed.
door_airlock_surface_unlocked_opened → enter_surface_from_airlock: (N) – The door may fail to unlock or open.
door_habitat_airlock_locked_closed → enter_surface_from_airlock: (Y) – Locking the habitat door is standard protocol before this action.
robot_outside_habitat → enter_airlock_from_surface: (Y) – The robot can reach this state unless external obstructions occur.
door_airlock_surface_unlocked_opened → enter_airlock_from_surface: (N) – Similar risks to #9 regarding door mechanisms.
door_habitat_airlock_locked_closed → enter_airlock_from_surface: (Y) – This is a standard, maintainable condition during airlock operations.
robot_inside_airlock → enter_habitat_from_airlock: (Y) – Achievable if previous airlock operations are successful.
door_habitat_airlock_unlocked_opened → enter_habitat_from_airlock: (N) – Door mechanism issues could prevent this.
door_airlock_surface_locked_closed → enter_habitat_from_airlock: (Y) – This condition is controlled during airlock procedures.
door_habitat_airlock_unlocked_opened → lock_close_door_habitat_airlock: (N) – Door may fail to lock due to mechanical issues.
door_airlock_surface_unlocked_opened → lock_close_door_airlock_surface: (N) – Similar to #17, locking mechanisms can fail.
Post-condition Achievements: 19. door_habitat_airlock_unlocked_opened after unlock_open_door_habitat_airlock: (N) – Mechanical failure may prevent full door opening. 20. door_airlock_surface_unlocked_opened after unlock_open_door_airlock_surface: (N) – Similar risk to #19. 21. robot_inside_airlock after enter_airlock_from_habitat: (Y) – Typically achievable unless unexpected obstruction occurs. 22. robot_outside_habitat after enter_surface_from_airlock: (Y) – Achievable under normal conditions. 23. robot_inside_airlock after enter_airlock_from_surface: (Y) – Generally achievable barring anomalies. 24. robot_inside_habitat after enter_habitat_from_airlock: (Y) – Normally achievable unless door malfunction occurs. 25. door_habitat_airlock_locked_closed after lock_close_door_habitat_airlock: (N) – Lock may fail mechanically. 26. door_airlock_surface_locked_closed after lock_close_door_airlock_surface: (N) – Similar to #25.

Post-condition Subtractions (Undoing States): 27. door_habitat_airlock_locked_closed undone after unlock_open_door_habitat_airlock: (N) – Lock may not disengage properly. 28. door_airlock_surface_locked_closed undone after unlock_open_door_airlock_surface: (N) – Similar risk to #27. 29. robot_inside_habitat undone after enter_airlock_from_habitat: (Y) – The robot physically moves, making this state invalid. 30. robot_inside_airlock undone after enter_surface_from_airlock: (Y) – Movement ensures this state is left behind. 31. robot_outside_habitat undone after enter_airlock_from_surface: (Y) – The robot’s transition ensures this. 32. robot_inside_airlock undone after enter_habitat_from_airlock: (Y) – Same reasoning as #30. 33. door_habitat_airlock_unlocked_opened undone after lock_close_door_habitat_airlock: (N) – Door may not fully close/lock. 34. door_airlock_surface_unlocked_opened undone after lock_close_door_airlock_surface: (N) – Similar to #33.

Would you like to adjust or discuss any specific assumptions further?
'''

# %% [markdown]
# ### [TODO: copy and paste output from ChatGPT into file for later reference]

# %% [markdown]
# ### Validate Assumptions and Save to File

# %%
# process text from ChatGPT
validated_assumptions = process_chatbot_hrrt3_text(assumptions, raw_text=hrrt3_raw_text)
# save to file
write_hrrt3_yaml(validated_assumptions, model_file)
# Out:
# ERROR: could not find in any assumption lists, parsed state robot_inside_habitat and action unlock_open_door_habitat_airlock:
# ERROR: could not find in any assumption lists, parsed state robot_has_key and action unlock_open_door_habitat_airlock:
# ERROR: could not find in any assumption lists, parsed state robot_inside_airlock and action unlock_open_door_airlock_surface:
# ERROR: could not find in any assumption lists, parsed state robot_has_key and action unlock_open_door_airlock_surface:
# ERROR: could not find in any assumption lists, parsed state robot_inside_habitat and action enter_airlock_from_habitat:
# ERROR: could not find in any assumption lists, parsed state door_habitat_airlock_unlocked_opened and action enter_airlock_from_habitat:
# ERROR: could not find in any assumption lists, parsed state door_airlock_surface_locked_closed and action enter_airlock_from_habitat:
# ...

# %% [markdown]
# ## HRRT Level 4

# %% [markdown]
# Please update the model to take into account the invalid state combinations and invalid action assumptions.

# %% [markdown]
# ### Prompt for ChatGPT: Reflection

# %%
# initialize HRRT Level 4
print("Please fill in the blanks to answer the following questions:")
print()
print()
print()
_, _, _, _ = hrrt4(kb, model,
                   validated_possibilities,
                   validated_assumptions,
                   interactive=False)
print()
print()
print()
print("Please respond to the state and action updates and the Blue Team reflection questions.")
# Out:
# Please fill in the blanks to answer the following questions:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-fb70f4a92b9a> in <cell line: 6>()
#       6 _, _, _, _ = hrrt4(kb, model,
#       7                    validated_possibilities,
# ----> 8                    validated_assumptions,
#       9                    interactive=False)
#      10 print()
#
# NameError: name 'validated_assumptions' is not defined

# %%
print("Please fill in the blanks to answer the following questions:")
print()
print()
print()
hrrt4_abridged_transcript()
print()
print()
print()
print("Please respond to the Blue Team reflection questions.")
# Out:
# Please fill in the blanks to answer the following questions:
#
#
#
#
# ==================== HRRT LEVEL 4 REFLECTIONS ====================
#
# What important information may still be missing from the model?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ...
#
# What should an agent know when completing tasks in this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ...
#
# What catastrophic failures could occur in this domain?
# ...

# %% [markdown]
# ### [TODO: copy and paste output into ChatGPT]

# %% [markdown]
# ### ChatGPT's Reflection Response

# %%
hrrt4_reflection_raw_text = '''
'''

# %% [markdown]
# ### [TODO: copy and paste output from ChatGPT into file for later reference]

# %% [markdown]
# ### Prompt for ChatGPT: Model Update

# %%
print("How would you reformat the model I gave you to address the issues you found? Please add/remove states and actions as necessary, including anything you suggested earlier. Format it as a YAML the same way I did.")
# Out:
# How would you reformat the model I gave you to address the issues you found? Please add/remove states and actions as necessary, including anything you suggested earlier. Format it as a YAML the same way I did.

# %% [markdown]
# ### [TODO: copy and paste output into ChatGPT]

# %% [markdown]
# ### ChatGPT's Reflection Response

# %%
hrrt4_yaml_update_raw_text = '''
'''

# %% [markdown]
# ### [TODO: copy and paste output from ChatGPT into file for later reference]

# %% [markdown]
# ### Validate Knowledge Base and Model Updates and Save to File

# %%
# process text from ChatGPT to update knowledge base
updated_kb = process_chatbot_hrrt4_reflection_text(kb,
                                                   raw_text=hrrt4_reflection_raw_text)
# process text from ChatGPT to update model
updated_model = process_chatbot_hrrt4_updated_yaml(raw_text=hrrt4_yaml_update_raw_text)
# save to files
write_hrrt4_yaml(updated_kb=updated_kb, updated_model=updated_model,
                 model_hypothesis=([],[],[],[]), facts=[],
                 kb_file=kb_file, model_file=model_file)
