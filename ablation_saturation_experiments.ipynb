# %% [markdown]
# # Colab/Drive Setup

# %%
from google.colab import drive
from google.colab import runtime
drive.mount('/content/gdrive')
# %cd gdrive/MyDrive/Object\ Affordances/HRRT/human_robot_red_teaming
# %ls
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Object Affordances/HRRT/human_robot_red_teaming
# ablation_saturation_experiments.ipynb  docs/                            pyperplan/
# chatbot_hrrting.ipynb                  hrrt_testing.ipynb               README.md
# config/                                model_planning_evaluation.ipynb  scripts/

# %% [markdown]
# # Domain Prompts

# %% [markdown]
# ## Mars Science Team
#
# Scenario: A robot is on the Mars surface, conducting science experiments to learn about the feasibility of humans living long-term in space. The robot is working on a team of robots, and they have communication with ground control on Earth. Due to the long distance between Earth and Mars, the robots must handle time-delayed communications.

# %% [markdown]
# # General Instructions
#
# Goal: We need to make sure the robot has a sufficiently complex model of the scenario to perform tasks safely.
#
# The robot's model consists of states (predicates) and actions (name, pre-condition states, and post-condition states). You will be prompted with questions to explore the robot's model and provide improvements.
#
# Here's the robot's model (formatted as a PDDL file):

# %% [markdown]
# ## [TODO: copy model PDDL file into ChatGPT]

# %% [markdown]
# # Simplified Prompts (Used in Favor of More Detailed Prompts Below)

# %% [markdown]
# * Give ChatGPT initial prompt based on Domain Prompt and General Instructions, above.
# * Level 2:
#     * If ChatGPT does not offer initial reflections, prompt: "Please tell me about invalid state combinations [in your revised model]."
#     * Alternatively, more detailed prompt: "Thank you! Please tell me about invalid state combinations that are allowed (but shouldn't be) in your revised model."
#     * After initial suggestions, prompt: "Please update the model to [1-3 suggestions, use words directly from ChatGPT]?"
#     * SAVE ALL INTERATIONS AND SAVE MODEL.
# * Level 3:
#     * After revisions, prompt: "Please tell me about action feasibility and assumption inconsistencies in your revised model."
#     * After initial suggestions, prompt: "Please update the model to [1-3 suggestions, use words directly from ChatGPT]?"
#     * SAVE ALL INTERATIONS AND SAVE MODEL.
# * Level 4:
#     * After revisions, share reflection questions: [See prompt below]
#     * After these reflections, prompt: "Thank you! Please update your revised model to include [1-3 suggestions, use words directly from ChatGPT]."
#     * Alternatively, use the more general prompt: "What are the most severe failure modes and what could the robot do to mitigate the risks of these failures? Please update the model accordingly to include these risk mitigation actions."
#     * SAVE ALL INTERATIONS AND SAVE MODEL.
# * May need to prompt: "Please show me the revised model in PDDL format."
# * IMPORTANT REMINDERS:
#     * SAVE ALL INTERMEDIATE ITERATIONS OF MODEL IN CASE CHATGPT OVERWRITES IT
#     * ARCHIVE CHAT, something like "[domain name] HRRT - Iterations 1-5"
#
# ## Reflection Prompt
#
# ```
# Perfect, thank you! Let's use that as our new model. Please consider the following questions:
#
# ==================== HRRT LEVEL 4 REFLECTIONS ====================
#
# Are there additional tasks the robot should be taking on?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# What important information may still be missing from the model?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# What should an agent know when completing tasks in this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# What catastrophic failures could occur in this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# Are there external, independently verified resources for identifying failure cases in this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# What are undesirable outcomes (not necessarily catastrophic failures) for this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# How much can an agent trust other agents in this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# What are unlikely or remote possibilities that may occur in this domain?
#     Blue Team, please enter thoughts for this question
# [HUMAN-ROBOT BLUE TEAM RESPONSE]:
#     __________
#     __________
#     _____(more thoughts if needed)_____
#
#     Red Team, please prompt chat bot with thoughts for this question
# [HUMAN-ROBOT RED TEAM RESPONSE]:
#     (add thoughts here)
#
# ============================================================
#
# Please respond to the Blue Team reflection questions.
# ```
